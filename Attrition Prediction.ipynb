# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
cols = ["Education","EnvironmentSatisfaction","HourlyRate","BusinessTravel",
        "Department","EducationField","Attrition","JobRole","JobLevel","JobInvolvement",
        "JobSatisfaction","MaritalStatus","JobRole"]

# %%
for i in cols:
    print(f"{i} :")
    print(data[i].value_counts())
    print(data[i].unique())
    print("\n")
# Out:
# Education :
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# [2 1 4 3 5]
#
#
# EnvironmentSatisfaction :
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64
# [2 3 4 1]
#
#
# HourlyRate :
# 66    29
# 42    28
# 98    28
# 84    28
# 48    28
#       ..
# 69    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64
# [ 94  61  92  56  40  79  81  67  44  84  49  31  93  50  51  80  96  78
#   45  82  53  83  58  72  48  42  41  86  97  75  33  37  73  98  36  47
#   71  30  43  99  59  95  57  76  87  66  55  32  52  70  62  64  63  60
#  100  46  39  77  35  91  54  34  90  65  88  85  89  68  69  74  38]
#
#
# BusinessTravel :
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# Department :
# Research & Development    961
# ...

# %%
pd.set_option('max_columns', 35)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data['Attrition'].replace({'No':0,'Yes':1},inplace=True)
data['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
data[['JobInvolvement', 'Attrition']].groupby(['JobInvolvement'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
# Out:
#    JobInvolvement  Attrition
# 0               1   0.337349
# 1               2   0.189333
# 2               3   0.144009
# 3               4   0.090278

# %%
c = data[['JobSatisfaction', 'Attrition']].groupby(['JobSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    JobSatisfaction  Attrition
# 0                1   0.228374
# 2                3   0.165158
# 1                2   0.164286
# 3                4   0.113290

# %%
c = data[['JobRole', 'Attrition']].groupby(['JobRole'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#                      JobRole  Attrition
# 8       Sales Representative   0.397590
# 2      Laboratory Technician   0.239382
# 1            Human Resources   0.230769
# 7            Sales Executive   0.174847
# 6         Research Scientist   0.160959
# 4     Manufacturing Director   0.068966
# 0  Healthcare Representative   0.068702
# 3                    Manager   0.049020
# 5          Research Director   0.025000

# %%
c = data[['Gender', 'Attrition']].groupby(['Gender'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    Gender  Attrition
# 1    Male   0.170068
# 0  Female   0.147959

# %%
c = data[['EnvironmentSatisfaction', 'Attrition']].groupby(['EnvironmentSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    EnvironmentSatisfaction  Attrition
# 0                        1   0.253521
# 1                        2   0.149826
# 2                        3   0.136865
# 3                        4   0.134529

# %%
c = data[['JobLevel', 'Attrition']].groupby(['JobLevel'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    JobLevel  Attrition
# 0         1   0.263352
# 2         3   0.146789
# 1         2   0.097378
# 4         5   0.072464
# 3         4   0.047170

# %%
import seaborn as sns
g = sns.FacetGrid(data, col='Attrition')
g.map(plt.hist, 'MonthlyIncome', bins=20)

# %%
grid = sns.FacetGrid(data, col='Attrition', row='JobLevel', size=2.2, aspect=1.6)
grid.map(plt.hist, 'MonthlyIncome', alpha=.5, bins=20)
grid.add_legend();
# Out:
# E:\Conda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
grid = sns.FacetGrid(data, col='Attrition', row='JobRole', size=2.2, aspect=1.6)
grid.map(plt.hist, 'MonthlyIncome', alpha=.5, bins=20)
grid.add_legend()
# Out:
# E:\Conda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
grid = sns.FacetGrid(data, col='Attrition', row='EnvironmentSatisfaction', size=2.2, aspect=1.6)
grid.map(plt.hist, 'MonthlyIncome', alpha=.5, bins=20)
grid.add_legend();
# Out:
# E:\Conda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# CREATING MEANINGFUL FEATURES

# %%
print(data[['JobSatisfaction', 'Attrition']].groupby(['JobSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
print(data[['RelationshipSatisfaction', 'Attrition']].groupby(['RelationshipSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
print(data[['EnvironmentSatisfaction', 'Attrition']].groupby(['EnvironmentSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
print(data[['WorkLifeBalance', 'Attrition']].groupby(['WorkLifeBalance'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
# Out:
#    JobSatisfaction  Attrition
# 0                1   0.228374
# 2                3   0.165158
# 1                2   0.164286
# 3                4   0.113290
#    RelationshipSatisfaction  Attrition
# 0                         1   0.206522
# 2                         3   0.154684
# 1                         2   0.148515
# 3                         4   0.148148
#    EnvironmentSatisfaction  Attrition
# 0                        1   0.253521
# 1                        2   0.149826
# 2                        3   0.136865
# 3                        4   0.134529
#    WorkLifeBalance  Attrition
# 0                1   0.312500
# 3                4   0.176471
# 1                2   0.168605
# 2                3   0.142217

# %%
data["Satisfaction"] = (data["EnvironmentSatisfaction"]+data["JobSatisfaction"]+data["RelationshipSatisfaction"]+data["WorkLifeBalance"])//4
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
print(data[['Satisfaction', 'Attrition']].groupby(['Satisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
# Out:
#    Satisfaction  Attrition
# 0             1   0.323529
# 1             2   0.180124
# 2             3   0.118443
# 3             4   0.000000

# %% [markdown]
# ENCODING CATEGORICAL FEATURES

# %%
data = data.drop(columns=['StandardHours','EmployeeCount', 'Over18',])
pd.set_option('max_columns', 35)
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# ...

# %%
d = {'Sales Representative':0,'Laboratory Technician':1,'Humon Resources':2, 'Sales Executive':3, 'Research Scientist':4,'Manufacturing Director':5,'Healthcare Representative':6,'Manager':7,'Research Director':8}
data['JobRole'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# ...

# %%
data['Gender'].replace({'Male':0,'Female':1},inplace = True)
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
d = {'Research & Development':0,'Sales':1,'Humon Resources':2}
data['Department'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41          1      Travel_Rarely       1102          1                 1
# 1   49          0  Travel_Frequently        279          0                 8
# 2   37          1      Travel_Rarely       1373          0                 2
# 3   33          0  Travel_Frequently       1392          0                 3
# 4   27          0      Travel_Rarely        591          0                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2       1
# 1          1  Life Sciences               2                        3       0
# 2          2          Other               4                        4       0
# 3          4  Life Sciences               5                        4       1
# 4          1        Medical               7                        1       0
#
# ...

# %%
d = {'Travel_Rarely':0,'Travel_Frequently':1,'Non-Travel':2}
data['BusinessTravel'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41          1               0       1102          1                 1
# 1   49          0               1        279          0                 8
# 2   37          1               0       1373          0                 2
# 3   33          0               1       1392          0                 3
# 4   27          0               0        591          0                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2       1
# 1          1  Life Sciences               2                        3       0
# 2          2          Other               4                        4       0
# 3          4  Life Sciences               5                        4       1
# 4          1        Medical               7                        1       0
#
# ...

# %% [markdown]
# FEATURE ENGINEERING

# %%
data["Satisfaction"] = (data["EnvironmentSatisfaction"]+data["JobSatisfaction"]+data["RelationshipSatisfaction"]+data["WorkLifeBalance"])//4
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41          1               0       1102          1                 1
# 1   49          0               1        279          0                 8
# 2   37          1               0       1373          0                 2
# 3   33          0               1       1392          0                 3
# 4   27          0               0        591          0                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2       1
# 1          1  Life Sciences               2                        3       0
# 2          2          Other               4                        4       0
# 3          4  Life Sciences               5                        4       1
# 4          1        Medical               7                        1       0
#
# ...

# %%
data["Years"] = (data["YearsAtCompany"]+data["YearsInCurrentRole"]+ data["YearsSinceLastPromotion"]+ data["YearsWithCurrManager"])//4
print(data.head())
data.corr()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41          1               0       1102          1                 1
# 1   49          0               1        279          0                 8
# 2   37          1               0       1373          0                 2
# 3   33          0               1       1392          0                 3
# 4   27          0               0        591          0                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2       1
# 1          1  Life Sciences               2                        3       0
# 2          2          Other               4                        4       0
# 3          4  Life Sciences               5                        4       1
# 4          1        Medical               7                        1       0
#
# ...

# %%
data['OverTime'].replace({'No':0,'Yes':1},inplace=True)
data['OverTime'].value_counts()
# Out:
# 0    1054
# 1     416
# Name: OverTime, dtype: int64

# %%
data.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205       -0.024751   0.010661
# Attrition                -0.159205   1.000000       -0.000074  -0.056652
# BusinessTravel           -0.024751  -0.000074        1.000000   0.004086
# DailyRate                 0.010661  -0.056652        0.004086   1.000000
# DistanceFromHome         -0.001686   0.077924        0.024469  -0.004985
# Education                 0.208034  -0.031373       -0.000757  -0.016806
# EmployeeNumber           -0.010145  -0.010577        0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369       -0.004174   0.018355
# Gender                    0.036311  -0.029453       -0.032981   0.011716
# HourlyRate                0.024287  -0.006846       -0.026528   0.023381
# JobInvolvement            0.029820  -0.130016       -0.039062   0.046135
# JobLevel                  0.509604  -0.169105       -0.019311   0.002966
# ...

# %%
data["NumCompaniesWorked"].value_counts()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
c = data[['NumCompaniesWorked', 'Attrition']].groupby(['NumCompaniesWorked'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    NumCompaniesWorked  Attrition
# 5                   5   0.253968
# 9                   9   0.230769
# 7                   7   0.229730
# 6                   6   0.228571
# 1                   1   0.188100
# 8                   8   0.122449
# 4                   4   0.122302
# 0                   0   0.116751
# 2                   2   0.109589
# 3                   3   0.100629

# %%
def fn(n):
    a = []
    for i in n:
        if i>4:
            a.append(1)
        else:
            a.append(0)
    return a

# %%
data["NumComp"] = fn(data["NumCompaniesWorked"])
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41          1               0       1102          1                 1
# 1   49          0               1        279          0                 8
# 2   37          1               0       1373          0                 2
# 3   33          0               1       1392          0                 3
# 4   27          0               0        591          0                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2       1
# 1          1  Life Sciences               2                        3       0
# 2          2          Other               4                        4       0
# 3          4  Life Sciences               5                        4       1
# 4          1        Medical               7                        1       0
#
# ...

# %%
data.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205       -0.024751   0.010661
# Attrition                -0.159205   1.000000       -0.000074  -0.056652
# BusinessTravel           -0.024751  -0.000074        1.000000   0.004086
# DailyRate                 0.010661  -0.056652        0.004086   1.000000
# DistanceFromHome         -0.001686   0.077924        0.024469  -0.004985
# Education                 0.208034  -0.031373       -0.000757  -0.016806
# EmployeeNumber           -0.010145  -0.010577        0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369       -0.004174   0.018355
# Gender                    0.036311  -0.029453       -0.032981   0.011716
# HourlyRate                0.024287  -0.006846       -0.026528   0.023381
# JobInvolvement            0.029820  -0.130016       -0.039062   0.046135
# JobLevel                  0.509604  -0.169105       -0.019311   0.002966
# ...

# %% [markdown]
# MODEL CREATION

# %%
from sklearn.linear_model import LogisticRegression   
from sklearn.model_selection import KFold 
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics
from sklearn.metrics import accuracy_score , f1_score

# %%
def classification_model(model, data, predictors, outcome):  
    #Fit the model:  
    model.fit(data[predictors],data[outcome])    
    #Make predictions on training set:  
    predictions = model.predict(data[predictors])    
    #Print accuracy  
    accuracy = metrics.accuracy_score(predictions,data[outcome])  
    print("Accuracy : %s" % "{0:.3%}".format(accuracy))
    #Perform k-fold cross-validation with 5 folds  
    kf = KFold(5,shuffle=True)  
    error = []  
    for train, test in kf.split(data):
        # Filter training data    
        train_predictors = (data[predictors].iloc[train,:])        
        # The target we're using to train the algorithm.    
        train_target = data[outcome].iloc[train]        
        # Training the algorithm using the predictors and target.    
        model.fit(train_predictors, train_target)
        #Record error from each cross-validation run    
        error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
     
    score = f1_score(data[outcome], predictions, average="macro")
    print('F-Measure: %.3f' % score)
    print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error))) 
    # %s is placeholder for data from format, next % is used to conert it into percentage
    #.3% is no. of decimals
    return model

# %%
output = 'Attrition'
model = RandomForestClassifier()
predict = ['Age','Satisfaction','JobInvolvement','JobLevel','MonthlyIncome']
           #,'StockOptionLevel']#,'TotalWorkingYears'] monthlyincome job level years overtime ,'TotalWorkingYears'
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 100.000%
# F-Measure: 1.000
# Cross-Validation Score : 82.721%
# Accuracy : 100.000%
# F-Measure: 1.000
# Cross-Validation Score : 81.088%

# %%
from sklearn.linear_model import LogisticRegression
output = 'Attrition'
model = LogisticRegression()
predict = ['Age','Satisfaction','JobInvolvement','JobLevel','MonthlyIncome']
           #,'StockOptionLevel']#,'TotalWorkingYears'] monthlyincome job level years overtime ,'TotalWorkingYears'
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.946%
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.810%
# E:\Conda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.neighbors import KNeighborsClassifier
output = 'Attrition'
model = KNeighborsClassifier()
predict = ['Age','Satisfaction','JobInvolvement','JobLevel','MonthlyIncome']
           #,'StockOptionLevel']#,'TotalWorkingYears'] monthlyincome job level years overtime ,'TotalWorkingYears'
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 84.626%
# F-Measure: 0.599
# Cross-Validation Score : 81.361%
# Accuracy : 84.626%
# F-Measure: 0.599
# Cross-Validation Score : 82.109%

# %%
from sklearn import svm
output = 'Attrition'
model = svm.SVC()
predict = ['Age','Satisfaction','JobInvolvement','JobLevel','MonthlyIncome']
           #,'StockOptionLevel']#,'TotalWorkingYears'] monthlyincome job level years overtime ,'TotalWorkingYears'
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.878%
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.878%
